# %%
import pandas as pd
rice = pd.read_csv("dataanalysis/data_input/rice.csv", index_col=0)

# %%
rice.unit_price
# Out:
# 1        128000.0
# 2        102750.0
# 3         64000.0
# 4         65000.0
# 5        124500.0
#            ...
# 11996    128000.0
# 11997     64000.0
# 11998     59990.0
# 11999     59500.0
# 12000     59500.0
# Name: unit_price, Length: 12000, dtype: float64

# %%
rice['unit_price']
# Out:
# 1        128000.0
# 2        102750.0
# 3         64000.0
# 4         65000.0
# 5        124500.0
#            ...
# 11996    128000.0
# 11997     64000.0
# 11998     59990.0
# 11999     59500.0
# 12000     59500.0
# Name: unit_price, Length: 12000, dtype: float64

# %%
rice.columns[6]
# Out:
# 'unit_price'

# %%
rice.iloc[:,[5]]
# Out:
#             format
# 1      supermarket
# 2       minimarket
# 3      supermarket
# 4       minimarket
# 5      supermarket
# ...            ...
# 11996  supermarket
# 11997   minimarket
# 11998  supermarket
# 11999   minimarket
# 12000   minimarket
#
# [12000 rows x 1 columns]

# %%
rice.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-902833c4dade> in <module>
# ----> 1 rice.shape()
#
# TypeError: 'tuple' object is not callable

# %%
rice.columns[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-ebed21737708> in <module>
# ----> 1 rice.columns[10]
#
# ~\Anaconda3\envs\data-analytics\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    4278         if is_scalar(key):
#    4279             key = com.cast_scalar_indexer(key)
# -> 4280             return getitem(key)
#    4281
#    4282         if isinstance(key, slice):
#
# IndexError: index 10 is out of bounds for axis 0 with size 10

# %% [markdown]
# clients = pd.read_csv('dataanalysis/data_input/companies.csv', index_col=1)
# clients.head()

# %%
growth = pd.read_csv('dataanalysis/data_input/companies.csv')
growth[growth.'Customer Name' == ]
# Out:
#   File "<ipython-input-46-8ce9dc490018>", line 2
#     growth[growth.'Customer Name']
#                                 ^
# SyntaxError: invalid syntax

# %%
elec = pd.read_csv('amazon-electronic.csv')
elec[elec.brand == "Razer"].head(15)
elec['unit_price'] = elec['unit_price'].replace(",",".",regex=True)
elec['unit_price'] = elec['unit_price'].replace("USD","",regex=True).astype('float64')
elec['unit_price'].describe()b
# Out:
# count    2519.000000
# mean      568.362060
# std       620.874159
# min         1.000000
# 25%       149.990000
# 50%       479.750000
# 75%       548.000000
# max      4199.990000
# Name: unit_price, dtype: float64

# %%
cond1 = elec.name.str.contains('razer', case = False)
elec_razer = elec.loc[cond1]
cond2 = elec_razer.name.str.contains('blade', case = False)
elec_rblade = elec_razer.loc[cond2]
elec_rblade
# Out:
#         id  product_id        date               categories  brand  \
# 116    135       42196  2017-03-10  Computers & Accessories  Razer
# 188    234       42196  2017-03-30  Computers & Accessories  Razer
# 233    286       42196  2017-04-04  Computers & Accessories  Razer
# 281    338       42196  2017-05-01  Computers & Accessories  Razer
# 328    393       42196  2017-05-09  Computers & Accessories  Razer
# 329    394       25144  2017-05-09  Computers & Accessories  Razer
# 406    486       42196  2017-05-31  Computers & Accessories  Razer
# 436    522       25144  2017-06-01  Computers & Accessories  Razer
# 463    555       25144  2017-06-29  Computers & Accessories  Razer
# 512    612       25144  2017-07-07  Computers & Accessories  Razer
# 546    648       42196  2017-07-08  Computers & Accessories  Razer
# 568    671       42196  2017-07-09  Computers & Accessories  Razer
# 569    672       25144  2017-07-09  Computers & Accessories  Razer
# ...
